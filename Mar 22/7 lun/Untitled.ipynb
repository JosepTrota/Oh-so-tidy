# %%
import nltk
import pandas as pd
import docx2txt
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
ourfile=docx2txt.process('Horseracing.docx')

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(ourfile)

# %%
tokens_lower=[token.lower() for token in tokens]

# %%
tokens_lower
# Out:
# ['thousands',
#  'of',
#  'racehorses',
#  'are',
#  'being',
#  'sent',
#  'to',
#  'slaughterhouses',
#  'in',
#  'britain',
#  'and',
#  'ireland',
#  ',',
#  'a',
#  'bbc',
#  'panorama',
#  'investigation',
#  'has',
#  'found',
#  '.',
#  'some',
#  'of',
#  'the',
#  'slaughtered',
#  'animals',
#  'were',
#  'once',
#  'owned',
#  'and',
#  'trained',
#  'by',
#  'some',
#  'of',
#  'the',
#  'biggest',
#  'names',
#  'in',
#  'racing',
#  '.',
#  'covert',
#  'recording',
#  'also',
#  'showed',
#  'how',
#  'rules',
#  'designed',
#  'to',
#  'protect',
#  'horses',
#  'from',
#  'a',
#  'cruel',
#  'death',
#  'appear',
#  'to',
#  'be',
#  'regularly',
#  'ignored',
#  'at',
#  'one',
#  'of',
#  'the',
#  'uk',
#  "'s",
#  'biggest',
#  'abattoirs',
#  '.',
#  'the',
#  'abattoir',
#  'told',
#  'the',
#  'bbc',
#  'it',
#  'did',
#  'not',
#  'accept',
#  'any',
#  'form',
#  'of',
#  'animal',
#  'abuse',
#  '.',
#  'one',
#  'expert',
#  'described',
#  'the',
# ...

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
len(tokens_lower)
# Out:
# 1155

# %%
freqdistl=nltk.FreqDist(tokens_lower)

# %%
word_freql=dict((word,freq) for word, freq in freqdistl.items() if not word.isdigit())

# %%
sorted_word_freql= sorted(word_freql.items(), key=lambda x:x[1], reverse=True)

# %%
clean_tokens_lower=[word for word in tokens_lower if word.isalpha()]

# %%
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')

# %%
clean_tokens_lower_without_stop=[word for word in clean_tokens_lower if not word in stop_words]

# %%
len(clean_tokens_lower_without_stop)
# Out:
# 513

# %%
new_words=clean_tokens_lower_without_stop

# %%
freqdistl2=nltk.FreqDist(new_words)

# %%
word_freql2=dict((word,freq) for word, freq in freqdistl2.items() if not word.isdigit())

# %%
sorted_word_freq2= sorted(word_freql2.items(), key=lambda x:x[1], reverse=True)

# %%
sorted_word_freq2
# Out:
# [('said', 18),
#  ('horses', 14),
#  ('racing', 13),
#  ('horse', 11),
#  ('ireland', 8),
#  ('animal', 8),
#  ('footage', 8),
#  ('panorama', 6),
#  ('animals', 6),
#  ('aid', 6),
#  ('abattoir', 5),
#  ('cameras', 5),
#  ('regulations', 5),
#  ('elliott', 5),
#  ('killed', 5),
#  ('racehorses', 4),
#  ('sent', 4),
#  ('bbc', 4),
#  ('trained', 4),
#  ('also', 4),
#  ('one', 4),
#  ('welfare', 4),
#  ('going', 4),
#  ('slaughtered', 3),
#  ('covert', 3),
#  ('rules', 3),
#  ('death', 3),
#  ('told', 3),
#  ('three', 3),
#  ('industry', 3),
#  ('recorded', 3),
#  ('shot', 3),
#  ('care', 3),
#  ('euthanised', 3),
#  ('prof', 3),
#  ('mills', 3),
#  ('got', 3),
#  ('thousands', 2),
#  ('slaughterhouses', 2),
#  ('britain', 2),
#  ('biggest', 2),
#  ('showed', 2),
#  ('designed', 2),
#  ('protect', 2),
#  ('appear', 2),
#  ('abattoirs', 2),
#  ('accept', 2),
#  ('form', 2),
#  ('abuse', 2),
#  ('expert', 2),
#  ('clear', 2),
#  ('breaches', 2),
#  ('gordon', 2),
#  ('fate', 2),
# ...

# %%
from nltk.text import Text

# %%
nltktext=Text(new_words)

# %%
type(nltktext)
# Out:
# nltk.text.Text

# %%
nltktext.collocations()
# Out:
# animal aid; accept form; dene stansall; designed protect; drury sons;
# four days; travelling miles; rules designed; former racehorses; gordon
# elliott; prof mills; animal abuse; britain ireland; form animal;
# racehorses slaughtered; told panorama; footage recorded; aid cameras;
# horses industry; horses shot

# %%
nltktext.concordance('horses')
# Out:
# Displaying 14 of 14 matches:
#  also showed rules designed protect horses cruel death appear regularly ignore
# d uproar also highlighted fate many horses industry die racing training abatto
#  sons abattoir england licence kill horses looked footage absolutely astounded
# red majority ireland majority young horses shot abattoir previous illustrious
# ma none three animals sent abattoir horses retired racing due injury said care
# y said care killed elliott said two horses sent horse dealer rehomed possible
# unnecessary cruelty regulations say horses killed sight footage recorded horse
# orses killed sight footage recorded horses shot together times four days filmi
# eras recorded slaughterman shooting horses close distance reviewing footage on
# tions accept form animal abuse said horses humanely destroyed occasions issues
# ffering dr donovan said bottom line horses euthanised could euthanised home si
# ...

# %%
nltktext.dispersion_plot(['horses', 'racing', 'racehorses', 'elliott', 'trainer'])

# %%
data=pd.read_csv('Womens Clothing E-Commerce Reviews.txt')

# %%
pd.set_option('display.max_colwidth', None)

# %%
data['Review Text']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Absolutely wonderful - silky and sexy and comfortable
# ...

# %%
TextBlob('Hate this shit. Garbage service, unsolicited slap in the face, never coming back').sentiment
# Out:
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.5666666666666668)

# %%
TextBlob('Best place ever. Instant classic, love the beautiful and nice ambient').sentiment
# Out:
# Sentiment(polarity=0.5194444444444445, subjectivity=0.6222222222222222)

# %%
TextBlob('Could be better.').sentiment
# Out:
# Sentiment(polarity=0.5, subjectivity=0.5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
data['Department Name'].unique()
# Out:
# array(['Intimate', 'Dresses', 'Bottoms', 'Tops', 'Jackets', 'Trend', nan],
#       dtype=object)

# %%
data.dropna(subset=['Review Text', 'Department Name'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22628 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               22628 non-null  int64
#  1   Clothing ID              22628 non-null  int64
#  2   Age                      22628 non-null  int64
#  3   Title                    19662 non-null  object
#  4   Review Text              22628 non-null  object
#  5   Rating                   22628 non-null  int64
#  6   Recommended IND          22628 non-null  int64
#  7   Positive Feedback Count  22628 non-null  int64
#  8   Division Name            22628 non-null  object
#  9   Department Name          22628 non-null  object
#  10  Class Name               22628 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.1+ MB

# %%
from nltk.stem import WordNetLemmatizer

# %%
def cleaning(data):
    #1. Tokenize
    text_tokens = word_tokenize(data.replace("'", "").lower())
    #2. Remove Puncs
    tokens_without_punc = [w for w in text_tokens if w.isalpha()]
    #3. Removing Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
    #4. lemma
    text_cleaned = [WordNetLemmatizer().lemmatize(t) for t in tokens_without_sw]
    #joining
    return " ".join(text_cleaned)

# %%
cleaning(data['Review Text'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3940/1364638335.py in <module>
# ----> 1 cleaning(data['Review Text'])
#
# ~\AppData\Local\Temp/ipykernel_3940/3861106336.py in cleaning(data)
#       1 def cleaning(data):
#       2     #1. Tokenize
# ----> 3     text_tokens = word_tokenize(data.replace("'", "").lower())
#       4     #2. Remove Puncs
#       5     tokens_without_punc = [w for w in text_tokens if w.isalpha()]
#
# ~\anaconda3\envs\classclone\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'
